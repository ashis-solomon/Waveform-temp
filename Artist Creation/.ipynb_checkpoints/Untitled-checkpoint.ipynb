# %%
import pandas as pd
import numpy as np
import csv
import requests

# %%
df = pd.read_csv('artist_uris.csv',names=['ArtistID'])
print(len(df))
# Out:
# 81323

# %%
df
# Out:
#                                     ArtistID
# 0      spotify:artist:39EHxSQAIaWusRqSI9xoyF
# 1      spotify:artist:4tN3rZ7cChj4Wns2Wt2Nj6
# 2      spotify:artist:4HsOm6VNKZtGh8W8GhdNu4
# 3      spotify:artist:3LsQKoRgMc8VEkQn66jfAQ
# 4      spotify:artist:5KCG0FDMDPzQpxcohGUnyH
# ...                                      ...
# 81318  spotify:artist:53F8atvCmVFVOvnKwZXBd3
# 81319  spotify:artist:6VI0p0xTjBKKxQN8i8vGpD
# 81320  spotify:artist:7kaq0LysuRSgBZSorlZ7Vj
# 81321  spotify:artist:7MuuEryyseo5cvReO6gdPF
# 81322  spotify:artist:1easDqNuXyccZdonMosEiU
#
# [81323 rows x 1 columns]

# %%
for i in range(len(df)):
    df['ArtistID'][i] = df['ArtistID'][i].replace("spotify:artist:","")

# %%
df
# Out:
#                      ArtistID
# 0      39EHxSQAIaWusRqSI9xoyF
# 1      4tN3rZ7cChj4Wns2Wt2Nj6
# 2      4HsOm6VNKZtGh8W8GhdNu4
# 3      3LsQKoRgMc8VEkQn66jfAQ
# 4      5KCG0FDMDPzQpxcohGUnyH
# ...                       ...
# 81318  53F8atvCmVFVOvnKwZXBd3
# 81319  6VI0p0xTjBKKxQN8i8vGpD
# 81320  7kaq0LysuRSgBZSorlZ7Vj
# 81321  7MuuEryyseo5cvReO6gdPF
# 81322  1easDqNuXyccZdonMosEiU
#
# [81323 rows x 1 columns]

# %%
url = 'https://api.spotify.com/v1/artists/'
rel = '/related-artists'
headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': 'Bearer BQBtex9St2RNHTMCoDhZOOtCB8QWAUHkSjk0VDlZs8-lU6cs6LuuHUrt5WVbKSHlyhmuAl3VwvjBFtcMYP6E3xFoLFqfO5y8k18R4GuKubUY_AfDHkrJ0lFEWTtZqHFEm3O48fsH-oRIPuq7nLFjjnfUPeixuV5msDfbbHBUOYecXdQ9jcGswOWQyqNoAu9iKZg',
}

resp = ["" for x in range(len(df))]

for i in range(100):
    temp = url+df['ArtistID'][i]+rel
    response = requests.get(temp, headers=headers)
    resp[i] = response.json()

# %%
resp[9]
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3lO5RPMHrXaSQJoaLCFDb6'},
#    'followers': {'href': None, 'total': 150},
#    'genres': [],
#    'href': 'https://api.spotify.com/v1/artists/3lO5RPMHrXaSQJoaLCFDb6',
#    'id': '3lO5RPMHrXaSQJoaLCFDb6',
#    'images': [],
#    'name': '2008 South Africa',
#    'popularity': 3,
#    'type': 'artist',
#    'uri': 'spotify:artist:3lO5RPMHrXaSQJoaLCFDb6'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3E2mHB3lJB7vtd3xkFBm8e'},
#    'followers': {'href': None, 'total': 51},
#    'genres': [],
#    'href': 'https://api.spotify.com/v1/artists/3E2mHB3lJB7vtd3xkFBm8e',
#    'id': '3E2mHB3lJB7vtd3xkFBm8e',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273aab2461f1d92ea1fb5c3165d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02aab2461f1d92ea1fb5c3165d',
#      'width': 300},
#     {'height': 64,
# ...

# %%
id = ["" for x in range(20)]
artist = ["" for x in range(20)]

for i in range(20):
    try:
        artist = resp[i]['artists']
        id[i] = artist[i]['id']
    except:
        print(f"Error at line {i}")
# Out:
# Error at line 2
# Error at line 5
# Error at line 15
# Error at line 17
# Error at line 18

# %%
print(id[1])
# Out:
# 30b9WulBM8sFuBo17nNq9c

# %%
print(id[2])

# %%
artist = resp[1]['artists']
uri = artist[1]['id']

print(uri)
# Out:
# 30b9WulBM8sFuBo17nNq9c
