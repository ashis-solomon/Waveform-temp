# %%
import pandas as pd
import numpy as np
import requests
import csv

# %%
file = open('workfile1.csv')
dataset = csv.reader(file)

rows = []
for row in dataset:
        rows.append(row)

print(len(rows))
# Out:
# 5620

# %%
print(len(rows[0]))

print(rows[0][0])

row_1 = ""

for i in range(50):
    row_1 += rows[0][i]+","
    
# print(row_1)

print(len(row_1)/len("66U0ASk1VHZsqIkpMjKX3B-"))
# Out:
# 50
# 66U0ASk1VHZsqIkpMjKX3B
# 50.0

# %%
print(len(rows))

data_row = ["" for x in range(len(rows))]

for i in range(len(rows)):
    count = 0
    for j in range(50):
        if count==0:
            data_row[i]=""
            count=1
        if(j<49):
            data_row[i] += rows[i][j]+"%2C"
        if(j==49):
            data_row[i] += rows[i][j]

print(len(data_row[0])/23)
print(len(data_row))

data_row[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 print(len(rows))
#       3 data_row = ["" for x in range(len(rows))]
#       5 for i in range(len(rows)):
#
# NameError: name 'rows' is not defined

# %%
url = 'https://api.spotify.com/v1/tracks'
access_token = ''
url0 = url+"?ids="+data_row[0]
url2 = "https://api.spotify.com/v1/tracks?ids=66U0ASk1VHZsqIkpMjKX3B%2C5MhsZlmKJG6X5kTHkdwC4B%2C0GZoB8h0kqXn7XFm4Sj06k%2C35kahykNu00FPysz3C2euR%2C3G6hD9B2ZHOsgf4WfNu7X1%2C6WQLkih8nE0JdUCEyLaGnQ%2C37sINbJZcFdHFAsVNsPq1i%2C0yhPEz5KxlDwckGJaMlZqM%2C5j9iuo3tMmQIfnEEQOOjxh%2C4eLSCSELtKxZwXnFbNLXT5%2C4PvD06Pmbm2rHG2JjSlElF%2C57nNNkgk768QVXq3uHxu5e%2C3y8AEUef1AVfr0npU5UOa9%2C5jJ69cMDMC0aeWPjZo6VP2%2C02b5L9jExmkRTdUTqXFzmR%2C6fKEplI9iN0JMHsRGQESaT%2C3ebXMykcMXOcLeJ9xZ17XH%2C1J9KJgXKFRqKGIzmJ7GjS3%2C6aBYg6Npa47VAqtEsLsUdz%2C0dA2Mk56wEzDgegdC6R17g%2C3ik1fFvzdgmVuiob8t8NlG%2C05BJQUM4bATKGFheqrC6CW%2C0rfGRC3ng0dxu0xZ3f1bWc%2C1azvKxDb5Vkph2KR7aq1Cx%2C1Gsv8f8KmowkF5BnfMIGKy%2C3KYiA4vq6RPO1dE2XROXd8%2C252pAlbltOjOcUux4dRtjp%2C1ynmMEK1fkyiZ6Z6F3ThEt%2C7vIyudiO2Tr9hZ2yzfwQmx%2C12yHvSYFXI7PGzNecUvIDu%2C6koWevx9MqN6efQ6qreIbm%2C2F46y5zSlBKOqco0k8xQAM%2C00YnfZzpODxlE6nNwfPCbv%2C3PiyMOuCTB4Rc624hRr2rC%2C6IE47jpPeatF2Iay7GZtEc%2C6BOtDFg6GJm0rPUDuNmx57%2C6F609ICg9Spjrw1epsAnpa%2C14WWzenpaEgQZlqPq2nk4v%2C1xznGGDReH1oQq0xzbwXa3%2C1vxw6aYJls2oq3gW0DujAo%2C1xznGGDReH1oQq0xzbwXa3%2C4tCtwWceOPWzenK2HAIJSb%2C2ZyuwVvV6Z3XJaXIFbspeE%2C7yHEDfrJNd0zWOfXwydNH0%2C3tRFqxTYOjeTmCiVaGDCsq%2C0wz1LjDb9ZNEYwOmDJ3Q4b%2C1AJ5F0FMTC3yFU3ocjy1gE%2C75WMOzv7195ziyx0qEw1yE%2C62fX8EW16l8St2yL8rMer9%2C6RrXd9Hph4hYR4bf3dbM6H"
# print(url1)
# print("\n\n")
# print(url2)

# print(url1==url2)
def get_SeveralTracks():
  response = requests.get(
      url1,
      headers={
          "Authorization":f"Bearer {access_token}",
#           "ids":data_row[0]
          }
      )
  resp = response.json()
  return resp

resp0 = get_SeveralTracks()
print(type(resp0))
# print(resp0)
# Out:
# <class 'dict'>
# {'tracks': [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/
N6efQ6qreIbm%2C2F46y5zSlBKOqco0k8xQAM%2C00YnfZzpODxlE6nNwfPCbv%2C3PiyMOuCTB4Rc624hRr2rC%2C6IE47jpPeatF2Iay7GZtEc%2C6BOtDFg6GJm0rPUDuNmx57%2C6F609ICg9Spjrw1epsAnpa%2C14WWzenpaEgQZlqPq2nk4v%2C1xznGGDReH1oQq0xzbwXa3%2C1vxw6aYJls2oq3gW0DujAo%2C1xznGGDReH1oQq0xzbwXa3%2C4tCtwWceOPWzenK2HAIJSb%2C2ZyuwVvV6Z3XJaXIFbspeE%2C7yHEDfrJNd0zWOfXwydNH0%2C3tRFqxTYOjeTmCiVaGDCsq%2C0wz1LjDb9ZNEYwOmDJ3Q4b%2C1AJ5F0FMTC3yFU3ocjy1gE%2C75WMOzv7195ziyx0qEw1yE%2C62fX8EW16l8St2yL8rMer9%2C6RrXd9Hph4hYR4bf3dbM6H"
# print(url1)
# print("\n\n")
# print(url2)

# print(url1==url2)
def get_SeveralTracks():
  response = requests.get(
      url1,
      headers={
          "Authorization":f"Bearer {access_token}",
#           "ids":data_row[0]
          }
      )
  resp = response.json()
  return resp

resp1 = get_SeveralTracks()
print(type(resp1))
# print(resp1)

print(len(resp1['tracks']))
# Out:
# <class 'dict'>
# 50

# %%
tracks = resp1['tracks']
print(len(tracks))

# print(tracks[0])

# print(tracks[0]['name'])
# print(tracks[0]['popularity'])

for i in range(len(tracks)):
    print(f"{i}  {tracks[i]['name']}  {tracks[i]['popularity']}")
# Out:
# 50
# 0  Mint Leaf  22
# 1  pink skies  0
# 2  Cough Syrup  70
# 3  Soap  73
# 4  Puzzle Pieces  14
# 5  Feels (feat. Pharrell Williams, Katy Perry & Big Sean)  80
# 6  I Like Me Better  7
# 7  Back to You (feat. Bebe Rexha & Digital Farm Animals)  68
# 8  New Rules  81
# 9  Strip That Down  1
# 10  Hold On Loosely  0
# 11  I'm Eighteen  58
# 12  Dream On  80
# 13  Wildflowers  68
# 14  Mary Jane's Last Dance  0
# 15  Come On Get Higher  71
# 16  Thunder Clatter  40
# 17  Rhythm Of Love  63
# 18  Landslide  62
# 19  Stolen Dance  74
# 20  Free Somebody  0
# 21  Keep On Doin'  0
# 22  All Mine  0
# 23  what U need  0
# 24  Why  0
# 25  Skeleton in the Closet (feat. Louis Armstrong)  0
# 26  Halloween Spooks  2
# 27  Nightmare  32
# 28  The Ghost of Smoky Joe  0
# 29  The Little Man Who Wasn't There (feat. Glenn Miller)  0
# 30  Coleccionista de Canciones  68
# 31  Mientes  72
# 32  Yo Quiero  42
# 33  De Mí  56
# 34  No Veo la Hora  53
# 35  Don't Lay Your Head  21
# 36  Come Back  21
# 37  No Matter Where You Are  55
# 38  Poison & Wine  0
# 39  Hold Back The River  64
# 40  Once In a While  60
# 41  A closeness  0
# 42  7 Years  52
# 43  The Wolf  0
# 44  Heartbeats  61
# 45  Creep  3
# 46  Smells Like Teen Spirit  79
# 47  Black Hole Sun  50
# 48  Give It Away  73
# 49  What I Got  48

# %%
print(tracks[0]['external_urls'])
                
print(tracks[49]['external_urls'])

for i in range(len(tracks)):
    track_url = tracks[i]['external_urls']
print(track_url)
# Out:
# {'spotify': 'https://open.spotify.com/track/31kTKEPu5PPTTODydIYai0'}
# {'spotify': 'https://open.spotify.com/track/5nkYHBWXu7KCgcdwP6jcB1'}
# {'spotify': 'https://open.spotify.com/track/5nkYHBWXu7KCgcdwP6jcB1'}
