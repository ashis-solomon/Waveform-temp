# %%
import pandas as pd
import numpy as np
import csv

# %%
df= pd.read_csv('comp1.csv', header=[0])
comp1 = pd.DataFrame(df)
comp1
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.890   0.672    7    -5.532     1       0.0621       0.70700
# 1             0.883   0.817    0    -5.414     1       0.2350       0.60100
# 2             0.586   0.626    1    -8.448     1       0.0356       0.08740
# 3             0.654   0.304    6    -9.067     0       0.0358       0.64700
# 4             0.690   0.578    6    -7.436     1       0.0929       0.16700
# ...             ...     ...  ...       ...   ...          ...           ...
# 24995         0.547   0.667    4    -7.278     1       0.0472       0.00453
# 24996         0.518   0.453    1    -5.934     1       0.0259       0.62600
# 24997         0.556   0.709    7    -3.932     1       0.0394       0.18500
# 24998         0.495   0.572    1    -4.668     1       0.0356       0.16600
# 24999         0.490   0.716    4    -6.681     1       0.0441       0.02200
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000604    0.1770   0.5980  126.036  audio_features
# 1              0.004490    0.1100   0.5950  128.078  audio_features
# 2              0.000380    0.1130   0.0519   94.965  audio_features
# 3              0.000072    0.1470   0.1020  113.992  audio_features
# 4              0.000000    0.3050   0.4160   99.961  audio_features
# ...                 ...       ...      ...      ...             ...
# 24995          0.000100    0.2450   0.3510  119.814  audio_features
# 24996          0.000000    0.0952   0.2060  147.939  audio_features
# 24997          0.000000    0.0811   0.2810  155.984  audio_features
# 24998          0.000000    0.0966   0.5370  204.090  audio_features
# 24999          0.000480    0.0526   0.2880   74.988  audio_features
#
#                            id                                   uri  \
# 0      66U0ASk1VHZsqIkpMjKX3B  spotify:track:66U0ASk1VHZsqIkpMjKX3B
# 1      5MhsZlmKJG6X5kTHkdwC4B  spotify:track:5MhsZlmKJG6X5kTHkdwC4B
# 2      0GZoB8h0kqXn7XFm4Sj06k  spotify:track:0GZoB8h0kqXn7XFm4Sj06k
# 3      35kahykNu00FPysz3C2euR  spotify:track:35kahykNu00FPysz3C2euR
# 4      3G6hD9B2ZHOsgf4WfNu7X1  spotify:track:3G6hD9B2ZHOsgf4WfNu7X1
# ...                       ...                                   ...
# 24995  2Ywfu6Y4aIu1B9txqWE3Ir  spotify:track:2Ywfu6Y4aIu1B9txqWE3Ir
# 24996  6IapKyPR2EARfGnN80htMB  spotify:track:6IapKyPR2EARfGnN80htMB
# 24997  4uEshHiW6ulFGPIlmusxXz  spotify:track:4uEshHiW6ulFGPIlmusxXz
# 24998  4nYlsPMvkX3I220O24Zm0F  spotify:track:4nYlsPMvkX3I220O24Zm0F
# 24999  4WnY4W5KrqglCdIus8X9Bo  spotify:track:4WnY4W5KrqglCdIus8X9Bo
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/66U0ASk1VHZs...
# 1      https://api.spotify.com/v1/tracks/5MhsZlmKJG6X...
# 2      https://api.spotify.com/v1/tracks/0GZoB8h0kqXn...
# 3      https://api.spotify.com/v1/tracks/35kahykNu00F...
# 4      https://api.spotify.com/v1/tracks/3G6hD9B2ZHOs...
# ...                                                  ...
# 24995  https://api.spotify.com/v1/tracks/2Ywfu6Y4aIu1...
# 24996  https://api.spotify.com/v1/tracks/6IapKyPR2EAR...
# 24997  https://api.spotify.com/v1/tracks/4uEshHiW6ulF...
# 24998  https://api.spotify.com/v1/tracks/4nYlsPMvkX3I...
# 24999  https://api.spotify.com/v1/tracks/4WnY4W5Krqgl...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/66U0...       163810
# 1      https://api.spotify.com/v1/audio-analysis/5Mhs...       166849
# 2      https://api.spotify.com/v1/audio-analysis/0GZo...       232507
# 3      https://api.spotify.com/v1/audio-analysis/35ka...       216600
# 4      https://api.spotify.com/v1/audio-analysis/3G6h...       193059
# ...                                                  ...          ...
# 24995  https://api.spotify.com/v1/audio-analysis/2Ywf...       206987
# 24996  https://api.spotify.com/v1/audio-analysis/6Iap...       258013
# 24997  https://api.spotify.com/v1/audio-analysis/4uEs...       236053
# 24998  https://api.spotify.com/v1/audio-analysis/4nYl...       149640
# 24999  https://api.spotify.com/v1/audio-analysis/4WnY...       286520
#
#        time_signature  popularity
# 0                   4          59
# 1                   4          72
# 2                   4           0
# 3                   4          58
# 4                   4          77
# ...               ...         ...
# 24995               4          26
# 24996               4          25
# 24997               4          19
# 24998               4          34
# 24999               4          60
#
# [25000 rows x 19 columns]

# %%
df= pd.read_csv('comp2.csv', header=[0])
comp2 = pd.DataFrame(df)
comp2
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.748   0.627    7    -6.029     1       0.0639      0.131000
# 1             0.527   0.793    3    -4.823     1       0.0352      0.108000
# 2             0.393   0.878    1    -3.705     1       0.0400      0.000022
# 3             0.510   0.532    2    -7.675     1       0.2900      0.023900
# 4             0.644   0.749    6    -6.531     0       0.0336      0.001630
# ...             ...     ...  ...       ...   ...          ...           ...
# 25167         0.501   0.720    2    -7.710     1       0.0320      0.133000
# 25168         0.619   0.629    1    -4.109     0       0.3300      0.047300
# 25169         0.184   0.399    7   -14.904     1       0.0457      0.563000
# 25170         0.408   0.941    7    -4.629     1       0.0551      0.165000
# 25171         0.899   0.724   10    -5.757     0       0.2020      0.015500
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000000    0.0852    0.524  120.963  audio_features
# 1              0.000003    0.1440    0.597  124.993  audio_features
# 2              0.000106    0.3750    0.500  152.283  audio_features
# 3              0.000000    0.1350    0.671   76.262  audio_features
# 4              0.863000    0.0735    0.755  174.065  audio_features
# ...                 ...       ...      ...      ...             ...
# 25167          0.000035    0.7490    0.452  108.595  audio_features
# 25168          0.227000    0.3140    0.262  123.003  audio_features
# 25169          0.124000    0.1340    0.136   66.983  audio_features
# 25170          0.003230    0.1070    0.846  126.967  audio_features
# 25171          0.000000    0.0453    0.778  133.950  audio_features
#
#                            id                                   uri  \
# 0      000xQL6tZNLJzIrtIgxqSl  spotify:track:000xQL6tZNLJzIrtIgxqSl
# 1      0010mZpCCwlPwoBiBsjoac  spotify:track:0010mZpCCwlPwoBiBsjoac
# 2      001m5KK2fu67yZ5ZW46LDZ  spotify:track:001m5KK2fu67yZ5ZW46LDZ
# 3      0032P9X3AD4AQvN7yzpmTo  spotify:track:0032P9X3AD4AQvN7yzpmTo
# 4      004XT7kCZUEJkVIZjmBdDi  spotify:track:004XT7kCZUEJkVIZjmBdDi
# ...                       ...                                   ...
# 25167  4mYMZPIsQsFA4spQuGClza  spotify:track:4mYMZPIsQsFA4spQuGClza
# 25168  4mYgJ5FdVxwBWL0Zvt96xG  spotify:track:4mYgJ5FdVxwBWL0Zvt96xG
# 25169  4mYjDXwOUL8sxWepdrnE6U  spotify:track:4mYjDXwOUL8sxWepdrnE6U
# 25170  4mYpkmfY0ycWAU3GTKGmRa  spotify:track:4mYpkmfY0ycWAU3GTKGmRa
# 25171  4mYvuqbaWcIP3RNn1mkOYP  spotify:track:4mYvuqbaWcIP3RNn1mkOYP
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/000xQL6tZNLJ...
# 1      https://api.spotify.com/v1/tracks/0010mZpCCwlP...
# 2      https://api.spotify.com/v1/tracks/001m5KK2fu67...
# 3      https://api.spotify.com/v1/tracks/0032P9X3AD4A...
# 4      https://api.spotify.com/v1/tracks/004XT7kCZUEJ...
# ...                                                  ...
# 25167  https://api.spotify.com/v1/tracks/4mYMZPIsQsFA...
# 25168  https://api.spotify.com/v1/tracks/4mYgJ5FdVxwB...
# 25169  https://api.spotify.com/v1/tracks/4mYjDXwOUL8s...
# 25170  https://api.spotify.com/v1/tracks/4mYpkmfY0ycW...
# 25171  https://api.spotify.com/v1/tracks/4mYvuqbaWcIP...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/000x...       188491
# 1      https://api.spotify.com/v1/audio-analysis/0010...       249947
# 2      https://api.spotify.com/v1/audio-analysis/001m...       194320
# 3      https://api.spotify.com/v1/audio-analysis/0032...       179478
# 4      https://api.spotify.com/v1/audio-analysis/004X...       219107
# ...                                                  ...          ...
# 25167  https://api.spotify.com/v1/audio-analysis/4mYM...       296053
# 25168  https://api.spotify.com/v1/audio-analysis/4mYg...       258133
# 25169  https://api.spotify.com/v1/audio-analysis/4mYj...       322219
# 25170  https://api.spotify.com/v1/audio-analysis/4mYp...       128960
# 25171  https://api.spotify.com/v1/audio-analysis/4mYv...       215600
#
#        time_signature  popularity
# 0                   4          58
# 1                   3          41
# 2                   4          36
# 3                   5           0
# 4                   4          49
# ...               ...         ...
# 25167               4           0
# 25168               4           0
# 25169               3          61
# 25170               4          39
# 25171               4          56
#
# [25172 rows x 19 columns]

# %%
# result_merge = pd.concat([comp1,comp2])
result_merge
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.890   0.672    7    -5.532     1       0.0621        0.7070
# 1             0.883   0.817    0    -5.414     1       0.2350        0.6010
# 2             0.586   0.626    1    -8.448     1       0.0356        0.0874
# 3             0.654   0.304    6    -9.067     0       0.0358        0.6470
# 4             0.690   0.578    6    -7.436     1       0.0929        0.1670
# ...             ...     ...  ...       ...   ...          ...           ...
# 25167         0.501   0.720    2    -7.710     1       0.0320        0.1330
# 25168         0.619   0.629    1    -4.109     0       0.3300        0.0473
# 25169         0.184   0.399    7   -14.904     1       0.0457        0.5630
# 25170         0.408   0.941    7    -4.629     1       0.0551        0.1650
# 25171         0.899   0.724   10    -5.757     0       0.2020        0.0155
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000604    0.1770   0.5980  126.036  audio_features
# 1              0.004490    0.1100   0.5950  128.078  audio_features
# 2              0.000380    0.1130   0.0519   94.965  audio_features
# 3              0.000072    0.1470   0.1020  113.992  audio_features
# 4              0.000000    0.3050   0.4160   99.961  audio_features
# ...                 ...       ...      ...      ...             ...
# 25167          0.000035    0.7490   0.4520  108.595  audio_features
# 25168          0.227000    0.3140   0.2620  123.003  audio_features
# 25169          0.124000    0.1340   0.1360   66.983  audio_features
# 25170          0.003230    0.1070   0.8460  126.967  audio_features
# 25171          0.000000    0.0453   0.7780  133.950  audio_features
#
#                            id                                   uri  \
# 0      66U0ASk1VHZsqIkpMjKX3B  spotify:track:66U0ASk1VHZsqIkpMjKX3B
# 1      5MhsZlmKJG6X5kTHkdwC4B  spotify:track:5MhsZlmKJG6X5kTHkdwC4B
# 2      0GZoB8h0kqXn7XFm4Sj06k  spotify:track:0GZoB8h0kqXn7XFm4Sj06k
# 3      35kahykNu00FPysz3C2euR  spotify:track:35kahykNu00FPysz3C2euR
# 4      3G6hD9B2ZHOsgf4WfNu7X1  spotify:track:3G6hD9B2ZHOsgf4WfNu7X1
# ...                       ...                                   ...
# 25167  4mYMZPIsQsFA4spQuGClza  spotify:track:4mYMZPIsQsFA4spQuGClza
# 25168  4mYgJ5FdVxwBWL0Zvt96xG  spotify:track:4mYgJ5FdVxwBWL0Zvt96xG
# 25169  4mYjDXwOUL8sxWepdrnE6U  spotify:track:4mYjDXwOUL8sxWepdrnE6U
# 25170  4mYpkmfY0ycWAU3GTKGmRa  spotify:track:4mYpkmfY0ycWAU3GTKGmRa
# 25171  4mYvuqbaWcIP3RNn1mkOYP  spotify:track:4mYvuqbaWcIP3RNn1mkOYP
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/66U0ASk1VHZs...
# 1      https://api.spotify.com/v1/tracks/5MhsZlmKJG6X...
# 2      https://api.spotify.com/v1/tracks/0GZoB8h0kqXn...
# 3      https://api.spotify.com/v1/tracks/35kahykNu00F...
# 4      https://api.spotify.com/v1/tracks/3G6hD9B2ZHOs...
# ...                                                  ...
# 25167  https://api.spotify.com/v1/tracks/4mYMZPIsQsFA...
# 25168  https://api.spotify.com/v1/tracks/4mYgJ5FdVxwB...
# 25169  https://api.spotify.com/v1/tracks/4mYjDXwOUL8s...
# 25170  https://api.spotify.com/v1/tracks/4mYpkmfY0ycW...
# 25171  https://api.spotify.com/v1/tracks/4mYvuqbaWcIP...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/66U0...       163810
# 1      https://api.spotify.com/v1/audio-analysis/5Mhs...       166849
# 2      https://api.spotify.com/v1/audio-analysis/0GZo...       232507
# 3      https://api.spotify.com/v1/audio-analysis/35ka...       216600
# 4      https://api.spotify.com/v1/audio-analysis/3G6h...       193059
# ...                                                  ...          ...
# 25167  https://api.spotify.com/v1/audio-analysis/4mYM...       296053
# 25168  https://api.spotify.com/v1/audio-analysis/4mYg...       258133
# 25169  https://api.spotify.com/v1/audio-analysis/4mYj...       322219
# 25170  https://api.spotify.com/v1/audio-analysis/4mYp...       128960
# 25171  https://api.spotify.com/v1/audio-analysis/4mYv...       215600
#
#        time_signature  popularity
# 0                   4          59
# 1                   4          72
# 2                   4           0
# 3                   4          58
# 4                   4          77
# ...               ...         ...
# 25167               4           0
# 25168               4           0
# 25169               3          61
# 25170               4          39
# 25171               4          56
#
# [50172 rows x 19 columns]

# %%
result_merge.drop_duplicates(keep=False,inplace=True)
result_merge
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.890   0.672    7    -5.532     1       0.0621        0.7070
# 1             0.883   0.817    0    -5.414     1       0.2350        0.6010
# 3             0.654   0.304    6    -9.067     0       0.0358        0.6470
# 4             0.690   0.578    6    -7.436     1       0.0929        0.1670
# 5             0.500   0.726    5    -4.124     1       0.0643        0.0362
# ...             ...     ...  ...       ...   ...          ...           ...
# 25166         0.690   0.678    1    -6.391     1       0.0281        0.3190
# 25167         0.501   0.720    2    -7.710     1       0.0320        0.1330
# 25168         0.619   0.629    1    -4.109     0       0.3300        0.0473
# 25170         0.408   0.941    7    -4.629     1       0.0551        0.1650
# 25171         0.899   0.724   10    -5.757     0       0.2020        0.0155
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000604    0.1770    0.598  126.036  audio_features
# 1              0.004490    0.1100    0.595  128.078  audio_features
# 3              0.000072    0.1470    0.102  113.992  audio_features
# 4              0.000000    0.3050    0.416   99.961  audio_features
# 5              0.000000    0.4410    0.397  125.904  audio_features
# ...                 ...       ...      ...      ...             ...
# 25166          0.000000    0.2640    0.802  118.675  audio_features
# 25167          0.000035    0.7490    0.452  108.595  audio_features
# 25168          0.227000    0.3140    0.262  123.003  audio_features
# 25170          0.003230    0.1070    0.846  126.967  audio_features
# 25171          0.000000    0.0453    0.778  133.950  audio_features
#
#                            id                                   uri  \
# 0      66U0ASk1VHZsqIkpMjKX3B  spotify:track:66U0ASk1VHZsqIkpMjKX3B
# 1      5MhsZlmKJG6X5kTHkdwC4B  spotify:track:5MhsZlmKJG6X5kTHkdwC4B
# 3      35kahykNu00FPysz3C2euR  spotify:track:35kahykNu00FPysz3C2euR
# 4      3G6hD9B2ZHOsgf4WfNu7X1  spotify:track:3G6hD9B2ZHOsgf4WfNu7X1
# 5      6WQLkih8nE0JdUCEyLaGnQ  spotify:track:6WQLkih8nE0JdUCEyLaGnQ
# ...                       ...                                   ...
# 25166  4mXldSx5L14Pd7JcVuam0P  spotify:track:4mXldSx5L14Pd7JcVuam0P
# 25167  4mYMZPIsQsFA4spQuGClza  spotify:track:4mYMZPIsQsFA4spQuGClza
# 25168  4mYgJ5FdVxwBWL0Zvt96xG  spotify:track:4mYgJ5FdVxwBWL0Zvt96xG
# 25170  4mYpkmfY0ycWAU3GTKGmRa  spotify:track:4mYpkmfY0ycWAU3GTKGmRa
# 25171  4mYvuqbaWcIP3RNn1mkOYP  spotify:track:4mYvuqbaWcIP3RNn1mkOYP
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/66U0ASk1VHZs...
# 1      https://api.spotify.com/v1/tracks/5MhsZlmKJG6X...
# 3      https://api.spotify.com/v1/tracks/35kahykNu00F...
# 4      https://api.spotify.com/v1/tracks/3G6hD9B2ZHOs...
# 5      https://api.spotify.com/v1/tracks/6WQLkih8nE0J...
# ...                                                  ...
# 25166  https://api.spotify.com/v1/tracks/4mXldSx5L14P...
# 25167  https://api.spotify.com/v1/tracks/4mYMZPIsQsFA...
# 25168  https://api.spotify.com/v1/tracks/4mYgJ5FdVxwB...
# 25170  https://api.spotify.com/v1/tracks/4mYpkmfY0ycW...
# 25171  https://api.spotify.com/v1/tracks/4mYvuqbaWcIP...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/66U0...       163810
# 1      https://api.spotify.com/v1/audio-analysis/5Mhs...       166849
# 3      https://api.spotify.com/v1/audio-analysis/35ka...       216600
# 4      https://api.spotify.com/v1/audio-analysis/3G6h...       193059
# 5      https://api.spotify.com/v1/audio-analysis/6WQL...       210013
# ...                                                  ...          ...
# 25166  https://api.spotify.com/v1/audio-analysis/4mXl...       181733
# 25167  https://api.spotify.com/v1/audio-analysis/4mYM...       296053
# 25168  https://api.spotify.com/v1/audio-analysis/4mYg...       258133
# 25170  https://api.spotify.com/v1/audio-analysis/4mYp...       128960
# 25171  https://api.spotify.com/v1/audio-analysis/4mYv...       215600
#
#        time_signature  popularity
# 0                   4          59
# 1                   4          72
# 3                   4          58
# 4                   4          77
# 5                   4           0
# ...               ...         ...
# 25166               4          38
# 25167               4           0
# 25168               4           0
# 25170               4          39
# 25171               4          56
#
# [31242 rows x 19 columns]

# %%
# result_merge.to_csv('merged_both.csv')
