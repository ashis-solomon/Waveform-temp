# %%
import pandas as pd
import numpy as np
import csv

# %%
df= pd.read_csv('comp11.csv', header=[0])
comp11 = pd.DataFrame(df)
comp11
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.890   0.672    7    -5.532     1       0.0621        0.7070
# 1             0.883   0.817    0    -5.414     1       0.2350        0.6010
# 2             0.586   0.626    1    -8.448     1       0.0356        0.0874
# 3             0.654   0.304    6    -9.067     0       0.0358        0.6470
# 4             0.690   0.578    6    -7.436     1       0.0929        0.1670
# ...             ...     ...  ...       ...   ...          ...           ...
# 54995         0.688   0.917    2    -7.449     1       0.0314        0.0185
# 54996         0.684   0.841   11    -9.094     0       0.0411        0.0403
# 54997         0.713   0.716    8   -11.493     1       0.0285        0.1140
# 54998         0.665   0.642    6    -9.771     1       0.0292        0.1870
# 54999         0.726   0.855    1    -7.530     0       0.0307        0.1280
#
# ...

# %%
df= pd.read_csv('comp22.csv', header=[0])
comp22 = pd.DataFrame(df)
comp22
# Out:
#                            id  popularity
# 0      000xQL6tZNLJzIrtIgxqSl          58
# 1      0010mZpCCwlPwoBiBsjoac          41
# 2      001m5KK2fu67yZ5ZW46LDZ          36
# 3      0032P9X3AD4AQvN7yzpmTo           0
# 4      004XT7kCZUEJkVIZjmBdDi          49
# ...                       ...         ...
# 41039  7zWBDQWvOLRU0NSgAeV4ro          21
# 41040  7zWSwQiRzpdB6BdU1NVblW          32
# 41041  7zWj09xkFgA9tcV6YhfU6q           0
# 41042  7zXAqmQ1E7LlcMdApK8Jdq          17
# 41043  7zXfy6kN7tOn3jxNRX1jW1           0
#
# [41044 rows x 2 columns]

# %%
result = pd.merge(comp11, comp22, on="id")

# %%
# result_merge.drop_duplicates(keep=False,inplace=True)
result
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.883   0.817    0    -5.414     1       0.2350       0.60100
# 1             0.586   0.626    1    -8.448     1       0.0356       0.08740
# 2             0.500   0.726    5    -4.124     1       0.0643       0.03620
# 3             0.490   0.885    3    -4.121     1       0.0396       0.00218
# 4             0.383   0.861    4    -2.816     0       0.0777       0.00380
# ...             ...     ...  ...       ...   ...          ...           ...
# 33984         0.792   0.771   11    -3.528     0       0.0398       0.02430
# 33985         0.679   0.755    9    -5.846     0       0.0332       0.02940
# 33986         0.688   0.917    2    -7.449     1       0.0314       0.01850
# 33987         0.713   0.716    8   -11.493     1       0.0285       0.11400
# 33988         0.665   0.642    6    -9.771     1       0.0292       0.18700
#
# ...

# %%
# result_merge.to_csv('merged_both.csv')
