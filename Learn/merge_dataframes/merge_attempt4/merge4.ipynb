# %%
import pandas as pd
import numpy as np
import csv

# %%
df= pd.read_csv('x_train.csv', header=[0])
x_train = pd.DataFrame(df)
x_train
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.890   0.672    7    -5.532     1       0.0621       0.70700
# 1             0.883   0.817    0    -5.414     1       0.2350       0.60100
# 2             0.586   0.626    1    -8.448     1       0.0356       0.08740
# 3             0.654   0.304    6    -9.067     0       0.0358       0.64700
# 4             0.690   0.578    6    -7.436     1       0.0929       0.16700
# ...             ...     ...  ...       ...   ...          ...           ...
# 64945         0.641   0.878    7    -4.605     0       0.0505       0.01810
# 64946         0.627   0.820    0    -4.698     0       0.0918       0.00455
# 64947         0.591   0.822    8    -4.000     1       0.2600       0.00715
# 64948         0.420   0.772   10    -6.728     1       0.2460       0.16700
# 64949         0.883   0.633    8    -8.229     1       0.4870       0.10300
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000604    0.1770   0.5980  126.036  audio_features
# 1              0.004490    0.1100   0.5950  128.078  audio_features
# 2              0.000380    0.1130   0.0519   94.965  audio_features
# 3              0.000072    0.1470   0.1020  113.992  audio_features
# 4              0.000000    0.3050   0.4160   99.961  audio_features
# ...                 ...       ...      ...      ...             ...
# 64945          0.000000    0.1150   0.3350  114.075  audio_features
# 64946          0.011700    0.0243   0.3530  190.092  audio_features
# 64947          0.000196    0.1470   0.2700   94.159  audio_features
# 64948          0.000001    0.3920   0.3780   72.635  audio_features
# 64949          0.000000    0.0508   0.8060  143.572  audio_features
#
#                            id                                   uri  \
# 0      66U0ASk1VHZsqIkpMjKX3B  spotify:track:66U0ASk1VHZsqIkpMjKX3B
# 1      5MhsZlmKJG6X5kTHkdwC4B  spotify:track:5MhsZlmKJG6X5kTHkdwC4B
# 2      0GZoB8h0kqXn7XFm4Sj06k  spotify:track:0GZoB8h0kqXn7XFm4Sj06k
# 3      35kahykNu00FPysz3C2euR  spotify:track:35kahykNu00FPysz3C2euR
# 4      3G6hD9B2ZHOsgf4WfNu7X1  spotify:track:3G6hD9B2ZHOsgf4WfNu7X1
# ...                       ...                                   ...
# 64945  6khDguAo8XXW1h0u7xofYk  spotify:track:6khDguAo8XXW1h0u7xofYk
# 64946  23NrifKtS1pQ9WAWI2SjBx  spotify:track:23NrifKtS1pQ9WAWI2SjBx
# 64947  2Gnif8YLgt23hXwF9bJaOL  spotify:track:2Gnif8YLgt23hXwF9bJaOL
# 64948  3FCNzOe8uXAz09X3fUDbz7  spotify:track:3FCNzOe8uXAz09X3fUDbz7
# 64949  2Tcsw4mrAUgTKVwf4ntI2t  spotify:track:2Tcsw4mrAUgTKVwf4ntI2t
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/66U0ASk1VHZs...
# 1      https://api.spotify.com/v1/tracks/5MhsZlmKJG6X...
# 2      https://api.spotify.com/v1/tracks/0GZoB8h0kqXn...
# 3      https://api.spotify.com/v1/tracks/35kahykNu00F...
# 4      https://api.spotify.com/v1/tracks/3G6hD9B2ZHOs...
# ...                                                  ...
# 64945  https://api.spotify.com/v1/tracks/6khDguAo8XXW...
# 64946  https://api.spotify.com/v1/tracks/23NrifKtS1pQ...
# 64947  https://api.spotify.com/v1/tracks/2Gnif8YLgt23...
# 64948  https://api.spotify.com/v1/tracks/3FCNzOe8uXAz...
# 64949  https://api.spotify.com/v1/tracks/2Tcsw4mrAUgT...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/66U0...       163810
# 1      https://api.spotify.com/v1/audio-analysis/5Mhs...       166849
# 2      https://api.spotify.com/v1/audio-analysis/0GZo...       232507
# 3      https://api.spotify.com/v1/audio-analysis/35ka...       216600
# 4      https://api.spotify.com/v1/audio-analysis/3G6h...       193059
# ...                                                  ...          ...
# 64945  https://api.spotify.com/v1/audio-analysis/6khD...       200760
# 64946  https://api.spotify.com/v1/audio-analysis/23Nr...       213360
# 64947  https://api.spotify.com/v1/audio-analysis/2Gni...       206893
# 64948  https://api.spotify.com/v1/audio-analysis/3FCN...       198659
# 64949  https://api.spotify.com/v1/audio-analysis/2Tcs...       232312
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 64945               4
# 64946               4
# 64947               4
# 64948               4
# 64949               4
#
# [64950 rows x 18 columns]

# %%
df= pd.read_csv('y_train.csv', header=[0])
y_train = pd.DataFrame(df)
y_train
# Out:
#                            id  \
# 0      66U0ASk1VHZsqIkpMjKX3B
# 1      5MhsZlmKJG6X5kTHkdwC4B
# 2      0GZoB8h0kqXn7XFm4Sj06k
# 3      35kahykNu00FPysz3C2euR
# 4      3G6hD9B2ZHOsgf4WfNu7X1
# ...                       ...
# 66095  3B4etxytImrRKQgV3XHjnR
# 66096  2KtS31kaWNHs12Q5B43Ixh
# 66097  25a7EWpbv4NjeUIP1PN6T1
# 66098  0MMyJUC3WNnFS1lit5pTjk
# 66099  4CdVzZTnf7JElTDw0kyUiN
#
#                                                     name  popularity
# 0                                           Little Swing          59
# 1                                       I'm an Albatraoz          72
# 2      Yellow Flicker Beat - From The Hunger Games: M...           0
# 3                                      White Teeth Teens          58
# 4                                                   Team          77
# ...                                                  ...         ...
# 66095                                  Harleys In Hawaii          76
# 66096                                         Right Here          71
# 66097                                                HOT          55
# 66098                                 jealousy, jealousy          84
# 66099                                   ...Ready For It?          42
#
# [66100 rows x 3 columns]

# %%
result = pd.merge( x_train, y_train, on="id")

# %%
# result_merge.drop_duplicates(keep=False,inplace=True)
result
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.890   0.672    7    -5.532     1       0.0621       0.70700
# 1             0.890   0.672    7    -5.532     1       0.0621       0.70700
# 2             0.883   0.817    0    -5.414     1       0.2350       0.60100
# 3             0.883   0.817    0    -5.414     1       0.2350       0.60100
# 4             0.586   0.626    1    -8.448     1       0.0356       0.08740
# ...             ...     ...  ...       ...   ...          ...           ...
# 64845         0.641   0.878    7    -4.605     0       0.0505       0.01810
# 64846         0.627   0.820    0    -4.698     0       0.0918       0.00455
# 64847         0.591   0.822    8    -4.000     1       0.2600       0.00715
# 64848         0.420   0.772   10    -6.728     1       0.2460       0.16700
# 64849         0.883   0.633    8    -8.229     1       0.4870       0.10300
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000604    0.1770   0.5980  126.036  audio_features
# 1              0.000604    0.1770   0.5980  126.036  audio_features
# 2              0.004490    0.1100   0.5950  128.078  audio_features
# 3              0.004490    0.1100   0.5950  128.078  audio_features
# 4              0.000380    0.1130   0.0519   94.965  audio_features
# ...                 ...       ...      ...      ...             ...
# 64845          0.000000    0.1150   0.3350  114.075  audio_features
# 64846          0.011700    0.0243   0.3530  190.092  audio_features
# 64847          0.000196    0.1470   0.2700   94.159  audio_features
# 64848          0.000001    0.3920   0.3780   72.635  audio_features
# 64849          0.000000    0.0508   0.8060  143.572  audio_features
#
#                            id                                   uri  \
# 0      66U0ASk1VHZsqIkpMjKX3B  spotify:track:66U0ASk1VHZsqIkpMjKX3B
# 1      66U0ASk1VHZsqIkpMjKX3B  spotify:track:66U0ASk1VHZsqIkpMjKX3B
# 2      5MhsZlmKJG6X5kTHkdwC4B  spotify:track:5MhsZlmKJG6X5kTHkdwC4B
# 3      5MhsZlmKJG6X5kTHkdwC4B  spotify:track:5MhsZlmKJG6X5kTHkdwC4B
# 4      0GZoB8h0kqXn7XFm4Sj06k  spotify:track:0GZoB8h0kqXn7XFm4Sj06k
# ...                       ...                                   ...
# 64845  6khDguAo8XXW1h0u7xofYk  spotify:track:6khDguAo8XXW1h0u7xofYk
# 64846  23NrifKtS1pQ9WAWI2SjBx  spotify:track:23NrifKtS1pQ9WAWI2SjBx
# 64847  2Gnif8YLgt23hXwF9bJaOL  spotify:track:2Gnif8YLgt23hXwF9bJaOL
# 64848  3FCNzOe8uXAz09X3fUDbz7  spotify:track:3FCNzOe8uXAz09X3fUDbz7
# 64849  2Tcsw4mrAUgTKVwf4ntI2t  spotify:track:2Tcsw4mrAUgTKVwf4ntI2t
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/66U0ASk1VHZs...
# 1      https://api.spotify.com/v1/tracks/66U0ASk1VHZs...
# 2      https://api.spotify.com/v1/tracks/5MhsZlmKJG6X...
# 3      https://api.spotify.com/v1/tracks/5MhsZlmKJG6X...
# 4      https://api.spotify.com/v1/tracks/0GZoB8h0kqXn...
# ...                                                  ...
# 64845  https://api.spotify.com/v1/tracks/6khDguAo8XXW...
# 64846  https://api.spotify.com/v1/tracks/23NrifKtS1pQ...
# 64847  https://api.spotify.com/v1/tracks/2Gnif8YLgt23...
# 64848  https://api.spotify.com/v1/tracks/3FCNzOe8uXAz...
# 64849  https://api.spotify.com/v1/tracks/2Tcsw4mrAUgT...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/66U0...       163810
# 1      https://api.spotify.com/v1/audio-analysis/66U0...       163810
# 2      https://api.spotify.com/v1/audio-analysis/5Mhs...       166849
# 3      https://api.spotify.com/v1/audio-analysis/5Mhs...       166849
# 4      https://api.spotify.com/v1/audio-analysis/0GZo...       232507
# ...                                                  ...          ...
# 64845  https://api.spotify.com/v1/audio-analysis/6khD...       200760
# 64846  https://api.spotify.com/v1/audio-analysis/23Nr...       213360
# 64847  https://api.spotify.com/v1/audio-analysis/2Gni...       206893
# 64848  https://api.spotify.com/v1/audio-analysis/3FCN...       198659
# 64849  https://api.spotify.com/v1/audio-analysis/2Tcs...       232312
#
#        time_signature                                               name  \
# 0                   4                                       Little Swing
# 1                   4                                       Little Swing
# 2                   4                                   I'm an Albatraoz
# 3                   4                                   I'm an Albatraoz
# 4                   4  Yellow Flicker Beat - From The Hunger Games: M...
# ...               ...                                                ...
# 64845               4                   I Can Only. (feat. Alessia Cara)
# 64846               4                       Baby By Me (Featuring Ne-Yo)
# 64847               4                              Do You Think About Me
# 64848               4                                   Don't Manipulate
# 64849               4                                      Cupid Shuffle
#
#        popularity
# 0              59
# 1              59
# 2              72
# 3              72
# 4               0
# ...           ...
# 64845          41
# 64846           0
# 64847           0
# 64848           0
# 64849          11
#
# [64850 rows x 20 columns]

# %%
# result.to_csv('initial_dataset64k.csv')

# %%
percent_gen = len(result)*100/(50*1325)
print(f"generated {percent_gen}%")
# Out:
# generated 97.88679245283019%
