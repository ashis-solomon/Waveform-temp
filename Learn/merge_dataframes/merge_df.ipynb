# %%
import pandas as pd
import numpy as np
import csv

# %%
df= pd.read_csv('x_train.csv', header=[0])
x_train = pd.DataFrame(df)
x_train
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.890   0.672    7    -5.532     1       0.0621        0.7070
# 1             0.883   0.817    0    -5.414     1       0.2350        0.6010
# 2             0.586   0.626    1    -8.448     1       0.0356        0.0874
# 3             0.654   0.304    6    -9.067     0       0.0358        0.6470
# 4             0.690   0.578    6    -7.436     1       0.0929        0.1670
# ...             ...     ...  ...       ...   ...          ...           ...
# 54995         0.688   0.917    2    -7.449     1       0.0314        0.0185
# 54996         0.684   0.841   11    -9.094     0       0.0411        0.0403
# 54997         0.713   0.716    8   -11.493     1       0.0285        0.1140
# 54998         0.665   0.642    6    -9.771     1       0.0292        0.1870
# 54999         0.726   0.855    1    -7.530     0       0.0307        0.1280
#
# ...

# %%
df= pd.read_csv('y_train.csv', header=[0])
y_train = pd.DataFrame(df)
y_train
# Out:
#                            id  \
# 0      66U0ASk1VHZsqIkpMjKX3B
# 1      5MhsZlmKJG6X5kTHkdwC4B
# 2      0GZoB8h0kqXn7XFm4Sj06k
# 3      35kahykNu00FPysz3C2euR
# 4      3G6hD9B2ZHOsgf4WfNu7X1
# ...                       ...
# 24995  2Ywfu6Y4aIu1B9txqWE3Ir
# 24996  6IapKyPR2EARfGnN80htMB
# 24997  4uEshHiW6ulFGPIlmusxXz
# 24998  4nYlsPMvkX3I220O24Zm0F
# 24999  4WnY4W5KrqglCdIus8X9Bo
#
#                                                     name  popularity
# 0                                           Little Swing          59
# 1                                       I'm an Albatraoz          72
# 2      Yellow Flicker Beat - From The Hunger Games: M...           0
# 3                                      White Teeth Teens          58
# 4                                                   Team          77
# ...                                                  ...         ...
# 24995   Need You Now - Jason Nevins Rhythmic Single Edit          26
# ...

# %%
# drop a row - syntax
# y_train.drop(y_train.index[0:6],axis=0,inplace=True)
# y_train

# %%
result = pd.merge(x_train, y_train, on="id")
result
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.890   0.672    7    -5.532     1       0.0621       0.70700
# 1             0.883   0.817    0    -5.414     1       0.2350       0.60100
# 2             0.586   0.626    1    -8.448     1       0.0356       0.08740
# 3             0.654   0.304    6    -9.067     0       0.0358       0.64700
# 4             0.690   0.578    6    -7.436     1       0.0929       0.16700
# ...             ...     ...  ...       ...   ...          ...           ...
# 24995         0.547   0.667    4    -7.278     1       0.0472       0.00453
# 24996         0.518   0.453    1    -5.934     1       0.0259       0.62600
# 24997         0.556   0.709    7    -3.932     1       0.0394       0.18500
# 24998         0.495   0.572    1    -4.668     1       0.0356       0.16600
# 24999         0.490   0.716    4    -6.681     1       0.0441       0.02200
#
# ...

# %%
# drop a column - syntax
# result = result.drop(["danceability"],axis=1)

# %%
# drop duplicates - syntax
# result.drop_duplicates(keep=False,inplace=True)
# result

# %%
# result = result.drop(["name"],axis=1)
result
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.890   0.672    7    -5.532     1       0.0621       0.70700
# 1             0.883   0.817    0    -5.414     1       0.2350       0.60100
# 2             0.586   0.626    1    -8.448     1       0.0356       0.08740
# 3             0.654   0.304    6    -9.067     0       0.0358       0.64700
# 4             0.690   0.578    6    -7.436     1       0.0929       0.16700
# ...             ...     ...  ...       ...   ...          ...           ...
# 24995         0.547   0.667    4    -7.278     1       0.0472       0.00453
# 24996         0.518   0.453    1    -5.934     1       0.0259       0.62600
# 24997         0.556   0.709    7    -3.932     1       0.0394       0.18500
# 24998         0.495   0.572    1    -4.668     1       0.0356       0.16600
# 24999         0.490   0.716    4    -6.681     1       0.0441       0.02200
#
# ...

# %%
# result.to_csv('comp1.csv')
