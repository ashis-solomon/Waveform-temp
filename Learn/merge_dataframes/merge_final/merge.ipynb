# %%
import pandas as pd
import numpy as np
import csv

# %%
df= pd.read_csv('result_1.csv', header=[0])
result_1 = pd.DataFrame(df)
result_1
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.890   0.672    7    -5.532     1       0.0621       0.70700
# 1             0.890   0.672    7    -5.532     1       0.0621       0.70700
# 2             0.883   0.817    0    -5.414     1       0.2350       0.60100
# 3             0.883   0.817    0    -5.414     1       0.2350       0.60100
# 4             0.586   0.626    1    -8.448     1       0.0356       0.08740
# ...             ...     ...  ...       ...   ...          ...           ...
# 64845         0.641   0.878    7    -4.605     0       0.0505       0.01810
# 64846         0.627   0.820    0    -4.698     0       0.0918       0.00455
# 64847         0.591   0.822    8    -4.000     1       0.2600       0.00715
# 64848         0.420   0.772   10    -6.728     1       0.2460       0.16700
# 64849         0.883   0.633    8    -8.229     1       0.4870       0.10300
#
# ...

# %%
print(len(result_1))
result_1 = result_1.drop_duplicates()
print(len(result_1))
# Out:
# 64800
# 64800

# %%
df= pd.read_csv('result_2.csv', header=[0])
result_2 = pd.DataFrame(df)
result_2
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.748   0.627    7    -6.029     1       0.0639      0.131000
# 1             0.527   0.793    3    -4.823     1       0.0352      0.108000
# 2             0.393   0.878    1    -3.705     1       0.0400      0.000022
# 3             0.510   0.532    2    -7.675     1       0.2900      0.023900
# 4             0.644   0.749    6    -6.531     0       0.0336      0.001630
# ...             ...     ...  ...       ...   ...          ...           ...
# 65895         0.399   0.625    2    -6.321     1       0.0295      0.017800
# 65896         0.721   0.858    0    -4.636     1       0.0869      0.000631
# 65897         0.727   0.736    5    -6.110     1       0.1840      0.212000
# 65898         0.568   0.698    0    -6.618     1       0.0445      0.146000
# 65899         0.562   0.497    3    -8.522     1       0.0333      0.619000
#
# ...

# %%
print(len(result_2))
result_2 = result_2.drop_duplicates()
print(len(result_2))
# Out:
# 65900
# 65900

# %%
result_merge = pd.concat([result_1,result_2])
result_merge
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.890   0.672    7    -5.532     1       0.0621      0.707000
# 2             0.883   0.817    0    -5.414     1       0.2350      0.601000
# 4             0.586   0.626    1    -8.448     1       0.0356      0.087400
# 6             0.654   0.304    6    -9.067     0       0.0358      0.647000
# 8             0.690   0.578    6    -7.436     1       0.0929      0.167000
# ...             ...     ...  ...       ...   ...          ...           ...
# 65895         0.399   0.625    2    -6.321     1       0.0295      0.017800
# 65896         0.721   0.858    0    -4.636     1       0.0869      0.000631
# 65897         0.727   0.736    5    -6.110     1       0.1840      0.212000
# 65898         0.568   0.698    0    -6.618     1       0.0445      0.146000
# 65899         0.562   0.497    3    -8.522     1       0.0333      0.619000
#
# ...

# %%
# result_merge.drop_duplicates(keep="first",inplace=True)
result_merge = result_merge.drop_duplicates()
result_merge
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.890   0.672    7    -5.532     1       0.0621      0.707000
# 2             0.883   0.817    0    -5.414     1       0.2350      0.601000
# 4             0.586   0.626    1    -8.448     1       0.0356      0.087400
# 6             0.654   0.304    6    -9.067     0       0.0358      0.647000
# 8             0.690   0.578    6    -7.436     1       0.0929      0.167000
# ...             ...     ...  ...       ...   ...          ...           ...
# 65654         0.550   0.913    7    -6.466     1       0.0557      0.000477
# 65663         0.913   0.505    6   -15.590     0       0.2850      0.083600
# 65754         0.666   0.664    3    -8.041     0       0.3370      0.606000
# 65794         0.459   0.322    7   -12.912     1       0.0595      0.816000
# 65818         0.375   0.815    5    -1.802     1       0.2080      0.562000
#
# ...

# %%
# result_merge.to_csv('final_result.csv')
# check the values -- 66250
