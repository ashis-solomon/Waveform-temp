# %%
import pandas as pd
import numpy as np
import csv

# %%
df= pd.read_csv('x_train.csv', header=[0])
x_train = pd.DataFrame(df)
x_train
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.303   0.616   10    -8.468     1       0.0373        0.2430
# 1             0.748   0.627    7    -6.029     1       0.0639        0.1310
# 2             0.491   0.324    2   -10.627     1       0.0442        0.6970
# 3             0.861   0.417    0    -8.083     0       0.0437        0.1620
# 4             0.750   0.808   10    -2.032     0       0.0840        0.0543
# ...             ...     ...  ...       ...   ...          ...           ...
# 24395         0.641   0.787    0    -4.271     1       0.0375        0.0268
# 24396         0.472   0.180    7   -18.835     1       0.0340        0.4960
# 24397         0.581   0.457    6    -7.924     0       0.0325        0.0131
# 24398         0.626   0.746    7    -8.832     1       0.0282        0.1600
# 24399         0.604   0.866    5    -6.742     1       0.0335        0.0151
#
# ...

# %%
df= pd.read_csv('y_train.csv', header=[0])
y_train = pd.DataFrame(df)
y_train
# Out:
#                            id  \
# 0      000mA0etY38nKdvf1N04af
# 1      000xQL6tZNLJzIrtIgxqSl
# 2      006AVH7fq061voGXkUiII4
# 3      006PJvsr6CyV3JdBf7wiNF
# 4      006yrnQMCZpiUgkR612gC8
# ...                       ...
# 24395  5YhAAlelWek228jZzxgEfr
# 24396  5Yi6mwvMHnnh241uGjcJYy
# 24397  5Yj5pG9BPF6p77d7BRF2bL
# 24398  5YjKdeES9QRJ8NmF4Xc8pV
# 24399  5YjY2B3RxitoHtkXFAdAe5
#
#                                                     name  popularity
# 0                       If I Gave Myself To Someone Else          16
# 1                   Still Got Time (feat. PARTYNEXTDOOR)          58
# 2                                             Fingertips          36
# 3      Crumble the Satellite (feat. Devin The Dude & ...           0
# 4                                                Caliber          37
# ...                                                  ...         ...
# 24395                                           Honestly          50
# ...

# %%
result = pd.merge(x_train, y_train, on="id")

# %%
# result_merge.drop_duplicates(keep=False,inplace=True)
result
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.303   0.616   10    -8.468     1       0.0373        0.2430
# 1             0.303   0.616   10    -8.468     1       0.0373        0.2430
# 2             0.748   0.627    7    -6.029     1       0.0639        0.1310
# 3             0.748   0.627    7    -6.029     1       0.0639        0.1310
# 4             0.491   0.324    2   -10.627     1       0.0442        0.6970
# ...             ...     ...  ...       ...   ...          ...           ...
# 24395         0.641   0.787    0    -4.271     1       0.0375        0.0268
# 24396         0.472   0.180    7   -18.835     1       0.0340        0.4960
# 24397         0.581   0.457    6    -7.924     0       0.0325        0.0131
# 24398         0.626   0.746    7    -8.832     1       0.0282        0.1600
# 24399         0.604   0.866    5    -6.742     1       0.0335        0.0151
#
# ...

# %%
print(len(result))
result.drop_duplicates(keep='first',inplace=True)
print(len(result))
# Out:
# 24400
# 24350

# %%
# result.to_csv('0-999.csv')

# %%
# result_merge.to_csv('merged_both.csv')
