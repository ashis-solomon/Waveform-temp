# %%
import pandas as pd
import numpy as np
import csv

# %%
df= pd.read_csv('x_train.csv', header=[0])
x_train = pd.DataFrame(df)
x_train
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.748  0.6270    7    -6.029     1       0.0639      0.131000
# 1             0.182  0.0334    8   -31.460     1       0.0474      0.985000
# 2             0.605  0.8460    9    -4.581     1       0.0778      0.000738
# 3             0.634  0.6640    0    -9.303     1       0.0406      0.177000
# 4             0.554  0.5170    5    -6.486     1       0.0309      0.551000
# ...             ...     ...  ...       ...   ...          ...           ...
# 36145         0.765  0.8370    1    -3.113     0       0.0320      0.001070
# 36146         0.757  0.4810    9   -10.515     1       0.0338      0.395000
# 36147         0.807  0.5510    4    -6.568     1       0.0333      0.008860
# 36148         0.707  0.6150    2    -5.750     1       0.0324      0.001340
# 36149         0.494  0.6890    9    -7.795     1       0.0288      0.069500
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000000    0.0852   0.5240  120.963  audio_features
# 1              0.561000    0.1140   0.0683   80.816  audio_features
# 2              0.000001    0.0530   0.7640  132.997  audio_features
# 3              0.003220    0.1270   0.7310  104.594  audio_features
# 4              0.000000    0.1760   0.3550  140.301  audio_features
# ...                 ...       ...      ...      ...             ...
# 36145          0.000011    0.0801   0.7210  122.028  audio_features
# 36146          0.000000    0.1120   0.9330  102.721  audio_features
# 36147          0.000205    0.2670   0.7800   93.006  audio_features
# 36148          0.040600    0.5610   0.1130   89.994  audio_features
# 36149          0.000006    0.0739   0.5740   93.883  audio_features
#
#                            id                                   uri  \
# 0      000xQL6tZNLJzIrtIgxqSl  spotify:track:000xQL6tZNLJzIrtIgxqSl
# 1      002PgfoyfrOGiKch4EW8Wm  spotify:track:002PgfoyfrOGiKch4EW8Wm
# 2      004skCQeDn1iLntSom0rRr  spotify:track:004skCQeDn1iLntSom0rRr
# 3      005CGalYNgMNZcvWMIFeK8  spotify:track:005CGalYNgMNZcvWMIFeK8
# 4      005X0FmdtkM1kiutosXLTR  spotify:track:005X0FmdtkM1kiutosXLTR
# ...                       ...                                   ...
# 36145  7zWj09xkFgA9tcV6YhfU6q  spotify:track:7zWj09xkFgA9tcV6YhfU6q
# 36146  7zXpBSwS6pC9R2if9cXT9H  spotify:track:7zXpBSwS6pC9R2if9cXT9H
# 36147  7zXqmgoZNRHNFgFAOoxhx6  spotify:track:7zXqmgoZNRHNFgFAOoxhx6
# 36148  7zbq8RT5Kd3ExOGVTiUQbR  spotify:track:7zbq8RT5Kd3ExOGVTiUQbR
# 36149  7zcJLcV1OXtW93cudSEJGh  spotify:track:7zcJLcV1OXtW93cudSEJGh
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/000xQL6tZNLJ...
# 1      https://api.spotify.com/v1/tracks/002PgfoyfrOG...
# 2      https://api.spotify.com/v1/tracks/004skCQeDn1i...
# 3      https://api.spotify.com/v1/tracks/005CGalYNgMN...
# 4      https://api.spotify.com/v1/tracks/005X0FmdtkM1...
# ...                                                  ...
# 36145  https://api.spotify.com/v1/tracks/7zWj09xkFgA9...
# 36146  https://api.spotify.com/v1/tracks/7zXpBSwS6pC9...
# 36147  https://api.spotify.com/v1/tracks/7zXqmgoZNRHN...
# 36148  https://api.spotify.com/v1/tracks/7zbq8RT5Kd3E...
# 36149  https://api.spotify.com/v1/tracks/7zcJLcV1OXtW...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/000x...       188491
# 1      https://api.spotify.com/v1/audio-analysis/002P...        46867
# 2      https://api.spotify.com/v1/audio-analysis/004s...       177773
# 3      https://api.spotify.com/v1/audio-analysis/005C...       321480
# 4      https://api.spotify.com/v1/audio-analysis/005X...       164347
# ...                                                  ...          ...
# 36145  https://api.spotify.com/v1/audio-analysis/7zWj...       195973
# 36146  https://api.spotify.com/v1/audio-analysis/7zXp...       148400
# 36147  https://api.spotify.com/v1/audio-analysis/7zXq...       323440
# 36148  https://api.spotify.com/v1/audio-analysis/7zbq...       421332
# 36149  https://api.spotify.com/v1/audio-analysis/7zcJ...       227733
#
#        time_signature
# 0                   4
# 1                   1
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 36145               4
# 36146               4
# 36147               4
# 36148               4
# 36149               4
#
# [36150 rows x 18 columns]

# %%
df= pd.read_csv('y_train.csv', header=[0])
y_train = pd.DataFrame(df)
y_train
# Out:
#                            id  \
# 0      000xQL6tZNLJzIrtIgxqSl
# 1      002PgfoyfrOGiKch4EW8Wm
# 2      004skCQeDn1iLntSom0rRr
# 3      005CGalYNgMNZcvWMIFeK8
# 4      005X0FmdtkM1kiutosXLTR
# ...                       ...
# 36045  7zWj09xkFgA9tcV6YhfU6q
# 36046  7zXpBSwS6pC9R2if9cXT9H
# 36047  7zXqmgoZNRHNFgFAOoxhx6
# 36048  7zbq8RT5Kd3ExOGVTiUQbR
# 36049  7zcJLcV1OXtW93cudSEJGh
#
#                                                     name  popularity
# 0                   Still Got Time (feat. PARTYNEXTDOOR)          58
# 1                                      Jasmine Runs Away          29
# 2      Heart and Soul - From "Camp Rock 2: The Final ...          46
# 3                                             LLorándote           0
# 4                       I Hear A Symphony - Mono Version           0
# ...                                                  ...         ...
# 36045                                           Drive By           0
# 36046                                       Bed Of Roses           0
# 36047                                   My Father's Eyes          51
# 36048                                     Hot Like Sauce          45
# 36049                                       It's A Shame          31
#
# [36050 rows x 3 columns]

# %%
result = pd.merge(x_train, y_train, on="id")

# %%
# result_merge.drop_duplicates(keep=False,inplace=True)
result
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.748  0.6270    7    -6.029     1       0.0639      0.131000
# 1             0.748  0.6270    7    -6.029     1       0.0639      0.131000
# 2             0.182  0.0334    8   -31.460     1       0.0474      0.985000
# 3             0.182  0.0334    8   -31.460     1       0.0474      0.985000
# 4             0.605  0.8460    9    -4.581     1       0.0778      0.000738
# ...             ...     ...  ...       ...   ...          ...           ...
# 36045         0.765  0.8370    1    -3.113     0       0.0320      0.001070
# 36046         0.757  0.4810    9   -10.515     1       0.0338      0.395000
# 36047         0.807  0.5510    4    -6.568     1       0.0333      0.008860
# 36048         0.707  0.6150    2    -5.750     1       0.0324      0.001340
# 36049         0.494  0.6890    9    -7.795     1       0.0288      0.069500
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000000    0.0852   0.5240  120.963  audio_features
# 1              0.000000    0.0852   0.5240  120.963  audio_features
# 2              0.561000    0.1140   0.0683   80.816  audio_features
# 3              0.561000    0.1140   0.0683   80.816  audio_features
# 4              0.000001    0.0530   0.7640  132.997  audio_features
# ...                 ...       ...      ...      ...             ...
# 36045          0.000011    0.0801   0.7210  122.028  audio_features
# 36046          0.000000    0.1120   0.9330  102.721  audio_features
# 36047          0.000205    0.2670   0.7800   93.006  audio_features
# 36048          0.040600    0.5610   0.1130   89.994  audio_features
# 36049          0.000006    0.0739   0.5740   93.883  audio_features
#
#                            id                                   uri  \
# 0      000xQL6tZNLJzIrtIgxqSl  spotify:track:000xQL6tZNLJzIrtIgxqSl
# 1      000xQL6tZNLJzIrtIgxqSl  spotify:track:000xQL6tZNLJzIrtIgxqSl
# 2      002PgfoyfrOGiKch4EW8Wm  spotify:track:002PgfoyfrOGiKch4EW8Wm
# 3      002PgfoyfrOGiKch4EW8Wm  spotify:track:002PgfoyfrOGiKch4EW8Wm
# 4      004skCQeDn1iLntSom0rRr  spotify:track:004skCQeDn1iLntSom0rRr
# ...                       ...                                   ...
# 36045  7zWj09xkFgA9tcV6YhfU6q  spotify:track:7zWj09xkFgA9tcV6YhfU6q
# 36046  7zXpBSwS6pC9R2if9cXT9H  spotify:track:7zXpBSwS6pC9R2if9cXT9H
# 36047  7zXqmgoZNRHNFgFAOoxhx6  spotify:track:7zXqmgoZNRHNFgFAOoxhx6
# 36048  7zbq8RT5Kd3ExOGVTiUQbR  spotify:track:7zbq8RT5Kd3ExOGVTiUQbR
# 36049  7zcJLcV1OXtW93cudSEJGh  spotify:track:7zcJLcV1OXtW93cudSEJGh
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/000xQL6tZNLJ...
# 1      https://api.spotify.com/v1/tracks/000xQL6tZNLJ...
# 2      https://api.spotify.com/v1/tracks/002PgfoyfrOG...
# 3      https://api.spotify.com/v1/tracks/002PgfoyfrOG...
# 4      https://api.spotify.com/v1/tracks/004skCQeDn1i...
# ...                                                  ...
# 36045  https://api.spotify.com/v1/tracks/7zWj09xkFgA9...
# 36046  https://api.spotify.com/v1/tracks/7zXpBSwS6pC9...
# 36047  https://api.spotify.com/v1/tracks/7zXqmgoZNRHN...
# 36048  https://api.spotify.com/v1/tracks/7zbq8RT5Kd3E...
# 36049  https://api.spotify.com/v1/tracks/7zcJLcV1OXtW...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/000x...       188491
# 1      https://api.spotify.com/v1/audio-analysis/000x...       188491
# 2      https://api.spotify.com/v1/audio-analysis/002P...        46867
# 3      https://api.spotify.com/v1/audio-analysis/002P...        46867
# 4      https://api.spotify.com/v1/audio-analysis/004s...       177773
# ...                                                  ...          ...
# 36045  https://api.spotify.com/v1/audio-analysis/7zWj...       195973
# 36046  https://api.spotify.com/v1/audio-analysis/7zXp...       148400
# 36047  https://api.spotify.com/v1/audio-analysis/7zXq...       323440
# 36048  https://api.spotify.com/v1/audio-analysis/7zbq...       421332
# 36049  https://api.spotify.com/v1/audio-analysis/7zcJ...       227733
#
#        time_signature                                               name  \
# 0                   4               Still Got Time (feat. PARTYNEXTDOOR)
# 1                   4               Still Got Time (feat. PARTYNEXTDOOR)
# 2                   1                                  Jasmine Runs Away
# 3                   1                                  Jasmine Runs Away
# 4                   4  Heart and Soul - From "Camp Rock 2: The Final ...
# ...               ...                                                ...
# 36045               4                                           Drive By
# 36046               4                                       Bed Of Roses
# 36047               4                                   My Father's Eyes
# 36048               4                                     Hot Like Sauce
# 36049               4                                       It's A Shame
#
#        popularity
# 0              58
# 1              58
# 2              29
# 3              29
# 4              46
# ...           ...
# 36045           0
# 36046           0
# 36047          51
# 36048          45
# 36049          31
#
# [36050 rows x 20 columns]

# %%
print(len(result))
result.drop_duplicates(keep='first',inplace=True)
print(len(result))
# Out:
# 36050
# 36000

# %%
# result.to_csv('1000-1999.csv')

# %%
# result_merge.to_csv('merged_both.csv')
