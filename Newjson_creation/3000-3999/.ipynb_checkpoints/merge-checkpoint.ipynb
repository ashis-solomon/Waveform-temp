# %%
import pandas as pd
import numpy as np
import csv

# %%
df= pd.read_csv('x_train.csv', header=[0])
x_train = pd.DataFrame(df)
x_train
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.748  0.6270    7    -6.029     1       0.0639      0.131000
# 1             0.732  0.9890    5    -4.172     0       0.0483      0.102000
# 2             0.182  0.0334    8   -31.460     1       0.0474      0.985000
# 3             0.547  0.3130    6    -7.729     1       0.0475      0.667000
# 4             0.673  0.6780   10    -5.960     0       0.0403      0.004140
# ...             ...     ...  ...       ...   ...          ...           ...
# 34795         0.428  0.8240    7    -5.022     1       0.0459      0.000058
# 34796         0.710  0.3040    6   -10.756     0       0.0332      0.702000
# 34797         0.599  0.9050    9    -2.477     1       0.1630      0.083500
# 34798         0.284  0.9100    6    -3.665     1       0.0752      0.005630
# 34799         0.196  0.0717    0   -21.197     1       0.0413      0.984000
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000000    0.0852   0.5240  120.963  audio_features
# 1              0.748000    0.0551   0.6840  127.984  audio_features
# 2              0.561000    0.1140   0.0683   80.816  audio_features
# 3              0.000000    0.0883   0.4340   49.835  audio_features
# 4              0.015100    0.2350   0.6270  130.009  audio_features
# ...                 ...       ...      ...      ...             ...
# 34795          0.000253    0.1260   0.2750  124.006  audio_features
# 34796          0.000008    0.0903   0.3120   98.037  audio_features
# 34797          0.000013    0.1190   0.8010  177.253  audio_features
# 34798          0.000000    0.0790   0.6190  100.326  audio_features
# 34799          0.917000    0.1110   0.0382  137.609  audio_features
#
#                            id                                   uri  \
# 0      000xQL6tZNLJzIrtIgxqSl  spotify:track:000xQL6tZNLJzIrtIgxqSl
# 1      002KbOVOX22zbNDwwnA0Wi  spotify:track:002KbOVOX22zbNDwwnA0Wi
# 2      002PgfoyfrOGiKch4EW8Wm  spotify:track:002PgfoyfrOGiKch4EW8Wm
# 3      005Pqv0PJC2XY8XSCNAkoP  spotify:track:005Pqv0PJC2XY8XSCNAkoP
# 4      005c2319jh47WwCfezqhms  spotify:track:005c2319jh47WwCfezqhms
# ...                       ...                                   ...
# 34795  7zZkPiqHnL7icGGb4Almf6  spotify:track:7zZkPiqHnL7icGGb4Almf6
# 34796  7zaZlzl0XhthNwH3GQcyZ0  spotify:track:7zaZlzl0XhthNwH3GQcyZ0
# 34797  7zbAWkXgOTFYVeymgGBt99  spotify:track:7zbAWkXgOTFYVeymgGBt99
# 34798  7zbc95yxuSRubmW8s5lwS7  spotify:track:7zbc95yxuSRubmW8s5lwS7
# 34799  7zbpbBslBEynrmnOEqMOHL  spotify:track:7zbpbBslBEynrmnOEqMOHL
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/000xQL6tZNLJ...
# 1      https://api.spotify.com/v1/tracks/002KbOVOX22z...
# 2      https://api.spotify.com/v1/tracks/002PgfoyfrOG...
# 3      https://api.spotify.com/v1/tracks/005Pqv0PJC2X...
# 4      https://api.spotify.com/v1/tracks/005c2319jh47...
# ...                                                  ...
# 34795  https://api.spotify.com/v1/tracks/7zZkPiqHnL7i...
# 34796  https://api.spotify.com/v1/tracks/7zaZlzl0Xhth...
# 34797  https://api.spotify.com/v1/tracks/7zbAWkXgOTFY...
# 34798  https://api.spotify.com/v1/tracks/7zbc95yxuSRu...
# 34799  https://api.spotify.com/v1/tracks/7zbpbBslBEyn...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/000x...       188491
# 1      https://api.spotify.com/v1/audio-analysis/002K...       210000
# 2      https://api.spotify.com/v1/audio-analysis/002P...        46867
# 3      https://api.spotify.com/v1/audio-analysis/005P...       147402
# 4      https://api.spotify.com/v1/audio-analysis/005c...       374827
# ...                                                  ...          ...
# 34795  https://api.spotify.com/v1/audio-analysis/7zZk...       235374
# 34796  https://api.spotify.com/v1/audio-analysis/7zaZ...       321053
# 34797  https://api.spotify.com/v1/audio-analysis/7zbA...       211000
# 34798  https://api.spotify.com/v1/audio-analysis/7zbc...       154520
# 34799  https://api.spotify.com/v1/audio-analysis/7zbp...       274274
#
#        time_signature
# 0                   4
# 1                   4
# 2                   1
# 3                   4
# 4                   4
# ...               ...
# 34795               4
# 34796               4
# 34797               4
# 34798               4
# 34799               5
#
# [34800 rows x 18 columns]

# %%
df= pd.read_csv('y_train.csv', header=[0])
y_train = pd.DataFrame(df)
y_train
# Out:
#                            id                                  name  \
# 0      000xQL6tZNLJzIrtIgxqSl  Still Got Time (feat. PARTYNEXTDOOR)
# 1      002KbOVOX22zbNDwwnA0Wi                    Yee - Original Mix
# 2      002PgfoyfrOGiKch4EW8Wm                     Jasmine Runs Away
# 3      005Pqv0PJC2XY8XSCNAkoP                     I've Been Waiting
# 4      005c2319jh47WwCfezqhms         Feel Your Love - Extended Mix
# ...                       ...                                   ...
# 34745  7zZkPiqHnL7icGGb4Almf6                               Reunion
# 34746  7zaZlzl0XhthNwH3GQcyZ0         Stranger Things Have Happened
# 34747  7zbAWkXgOTFYVeymgGBt99                  Aunque la Vida Duele
# 34748  7zbc95yxuSRubmW8s5lwS7                            I Like You
# 34749  7zbpbBslBEynrmnOEqMOHL                         Þú ert jörðin
#
#        popularity
# 0              58
# 1              20
# 2              29
# 3               0
# 4              17
# ...           ...
# 34745          45
# 34746          56
# 34747           0
# 34748           0
# 34749           3
#
# [34750 rows x 3 columns]

# %%
result = pd.merge(x_train, y_train, on="id")

# %%
# result_merge.drop_duplicates(keep=False,inplace=True)
result
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.748  0.6270    7    -6.029     1       0.0639      0.131000
# 1             0.748  0.6270    7    -6.029     1       0.0639      0.131000
# 2             0.732  0.9890    5    -4.172     0       0.0483      0.102000
# 3             0.732  0.9890    5    -4.172     0       0.0483      0.102000
# 4             0.182  0.0334    8   -31.460     1       0.0474      0.985000
# ...             ...     ...  ...       ...   ...          ...           ...
# 34745         0.428  0.8240    7    -5.022     1       0.0459      0.000058
# 34746         0.710  0.3040    6   -10.756     0       0.0332      0.702000
# 34747         0.599  0.9050    9    -2.477     1       0.1630      0.083500
# 34748         0.284  0.9100    6    -3.665     1       0.0752      0.005630
# 34749         0.196  0.0717    0   -21.197     1       0.0413      0.984000
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000000    0.0852   0.5240  120.963  audio_features
# 1              0.000000    0.0852   0.5240  120.963  audio_features
# 2              0.748000    0.0551   0.6840  127.984  audio_features
# 3              0.748000    0.0551   0.6840  127.984  audio_features
# 4              0.561000    0.1140   0.0683   80.816  audio_features
# ...                 ...       ...      ...      ...             ...
# 34745          0.000253    0.1260   0.2750  124.006  audio_features
# 34746          0.000008    0.0903   0.3120   98.037  audio_features
# 34747          0.000013    0.1190   0.8010  177.253  audio_features
# 34748          0.000000    0.0790   0.6190  100.326  audio_features
# 34749          0.917000    0.1110   0.0382  137.609  audio_features
#
#                            id                                   uri  \
# 0      000xQL6tZNLJzIrtIgxqSl  spotify:track:000xQL6tZNLJzIrtIgxqSl
# 1      000xQL6tZNLJzIrtIgxqSl  spotify:track:000xQL6tZNLJzIrtIgxqSl
# 2      002KbOVOX22zbNDwwnA0Wi  spotify:track:002KbOVOX22zbNDwwnA0Wi
# 3      002KbOVOX22zbNDwwnA0Wi  spotify:track:002KbOVOX22zbNDwwnA0Wi
# 4      002PgfoyfrOGiKch4EW8Wm  spotify:track:002PgfoyfrOGiKch4EW8Wm
# ...                       ...                                   ...
# 34745  7zZkPiqHnL7icGGb4Almf6  spotify:track:7zZkPiqHnL7icGGb4Almf6
# 34746  7zaZlzl0XhthNwH3GQcyZ0  spotify:track:7zaZlzl0XhthNwH3GQcyZ0
# 34747  7zbAWkXgOTFYVeymgGBt99  spotify:track:7zbAWkXgOTFYVeymgGBt99
# 34748  7zbc95yxuSRubmW8s5lwS7  spotify:track:7zbc95yxuSRubmW8s5lwS7
# 34749  7zbpbBslBEynrmnOEqMOHL  spotify:track:7zbpbBslBEynrmnOEqMOHL
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/000xQL6tZNLJ...
# 1      https://api.spotify.com/v1/tracks/000xQL6tZNLJ...
# 2      https://api.spotify.com/v1/tracks/002KbOVOX22z...
# 3      https://api.spotify.com/v1/tracks/002KbOVOX22z...
# 4      https://api.spotify.com/v1/tracks/002PgfoyfrOG...
# ...                                                  ...
# 34745  https://api.spotify.com/v1/tracks/7zZkPiqHnL7i...
# 34746  https://api.spotify.com/v1/tracks/7zaZlzl0Xhth...
# 34747  https://api.spotify.com/v1/tracks/7zbAWkXgOTFY...
# 34748  https://api.spotify.com/v1/tracks/7zbc95yxuSRu...
# 34749  https://api.spotify.com/v1/tracks/7zbpbBslBEyn...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/000x...       188491
# 1      https://api.spotify.com/v1/audio-analysis/000x...       188491
# 2      https://api.spotify.com/v1/audio-analysis/002K...       210000
# 3      https://api.spotify.com/v1/audio-analysis/002K...       210000
# 4      https://api.spotify.com/v1/audio-analysis/002P...        46867
# ...                                                  ...          ...
# 34745  https://api.spotify.com/v1/audio-analysis/7zZk...       235374
# 34746  https://api.spotify.com/v1/audio-analysis/7zaZ...       321053
# 34747  https://api.spotify.com/v1/audio-analysis/7zbA...       211000
# 34748  https://api.spotify.com/v1/audio-analysis/7zbc...       154520
# 34749  https://api.spotify.com/v1/audio-analysis/7zbp...       274274
#
#        time_signature                                  name  popularity
# 0                   4  Still Got Time (feat. PARTYNEXTDOOR)          58
# 1                   4  Still Got Time (feat. PARTYNEXTDOOR)          58
# 2                   4                    Yee - Original Mix          20
# 3                   4                    Yee - Original Mix          20
# 4                   1                     Jasmine Runs Away          29
# ...               ...                                   ...         ...
# 34745               4                               Reunion          45
# 34746               4         Stranger Things Have Happened          56
# 34747               4                  Aunque la Vida Duele           0
# 34748               4                            I Like You           0
# 34749               5                         Þú ert jörðin           3
#
# [34750 rows x 20 columns]

# %%
print(len(result))
result.drop_duplicates(keep='first',inplace=True)
print(len(result))
# Out:
# 34750
# 34700

# %%
# result.to_csv('3000-3999.csv')

# %%
# result_merge.to_csv('merged_both.csv')
