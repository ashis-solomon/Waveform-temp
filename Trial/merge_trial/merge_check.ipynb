# %%
import pandas as pd
import numpy as np
import csv

# %%
df= pd.read_csv('original.csv', header=None)
original = pd.DataFrame(df)
original
# Out:
#                           0                       1                       2   \
# 0     66U0ASk1VHZsqIkpMjKX3B  5MhsZlmKJG6X5kTHkdwC4B  0GZoB8h0kqXn7XFm4Sj06k
# 1     54i6YAQkZImwWjmzPrQeqd  1UqhkbzB1kuFwt2iy4h29Q  03f7xZmt2wHCIDJBFPK8G4
# 2     5kNe7PE09d6Kvw5pAsx23n  6GsAD8PgHxmEuIPTG8GP3M  6Knv6wdA0luoMUuuoYi2i1
# 3     7b4yGtR0rujvLi5EBfKKJ2  2IgLwduDgZ1sQ7JY4oMvq1  4oDZ5L8izBals6jKBJDBcX
# 4     0p1HtkrNYxv0iDfEKwXSTp  5g15o2Sm55Hn9ShK5yEXgp  5HGibWoxnkYSkl6mHmAlOE
# ...                      ...                     ...                     ...
# 1320  2yBkQxaXsNSAp6LpoAabAK  3bVwfHr4vuJv6DGZal2Dpq  3ns1Hn52RB28zGVHiFvz7W
# 1321  7H25ehG6xvB8K2ltLhbRJP  7ijRMBDIHLz7kDQdFcWq9b  0y2hmrcFl4a22VMXIHunJq
# 1322  4IIsES4fbqkI1zrp4n2hqz  2WUKigdj6FjOwty6hQM2ii  2ZQo43TnA0XBUvPHSUfe2F
# 1323  0d93luSGsze8wbwlPg3LIR  4aYMRDF9OQ7SJ3b1n25WV6  1ZsKNcPwMXfD8qHwBkRLP4
# 1324  0aAcuVJCmIkgVKzKHGfp1K  275PaZJ9uaoBAIl4Ltvdjx  3y8rFoxyr7qqUtHPUxl5QB
#
# ...

# %%
arr = np.array(original)
print(len(arr))
arr = arr.reshape(-1,1)
print(arr.shape)
original = pd.DataFrame(arr)
# Out:
# 1325
# (66250, 1)

# %%
original
# Out:
#                             0
# 0      66U0ASk1VHZsqIkpMjKX3B
# 1      5MhsZlmKJG6X5kTHkdwC4B
# 2      0GZoB8h0kqXn7XFm4Sj06k
# 3      35kahykNu00FPysz3C2euR
# 4      3G6hD9B2ZHOsgf4WfNu7X1
# ...                       ...
# 66245  3B4etxytImrRKQgV3XHjnR
# 66246  2KtS31kaWNHs12Q5B43Ixh
# 66247  25a7EWpbv4NjeUIP1PN6T1
# 66248  0MMyJUC3WNnFS1lit5pTjk
# 66249  4CdVzZTnf7JElTDw0kyUiN
#
# [66250 rows x 1 columns]

# %%
df= pd.read_csv('prob.csv', header=None)
prob = pd.DataFrame(df)
prob
# Out:
#                             0
# 0      66U0ASk1VHZsqIkpMjKX3B
# 1      5MhsZlmKJG6X5kTHkdwC4B
# 2      0GZoB8h0kqXn7XFm4Sj06k
# 3      35kahykNu00FPysz3C2euR
# 4      3G6hD9B2ZHOsgf4WfNu7X1
# ...                       ...
# 66254  7xyPTG4p3jedV8BOhuG818
# 66255  7y27iYV2YoJppMjeYzUHsg
# 66256  7ybo9jYmu57fKpUgbqgGw5
# 66257  7ytqdjooPEAa97QSu6NUHS
# 66258  7z47pgbZpkGcME2A0YxR0y
#
# [66259 rows x 1 columns]

# %%
# result = pd.merge(comp11, comp22, on="id")

# %%
result = pd.concat([original,prob])
result
# Out:
#                             0
# 0      66U0ASk1VHZsqIkpMjKX3B
# 1      5MhsZlmKJG6X5kTHkdwC4B
# 2      0GZoB8h0kqXn7XFm4Sj06k
# 3      35kahykNu00FPysz3C2euR
# 4      3G6hD9B2ZHOsgf4WfNu7X1
# ...                       ...
# 66254  7xyPTG4p3jedV8BOhuG818
# 66255  7y27iYV2YoJppMjeYzUHsg
# 66256  7ybo9jYmu57fKpUgbqgGw5
# 66257  7ytqdjooPEAa97QSu6NUHS
# 66258  7z47pgbZpkGcME2A0YxR0y
#
# [132509 rows x 1 columns]

# %%
res = result.drop_duplicates(keep=False,inplace=True)
print(len(res))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 2>()
#       1 res = result.drop_duplicates(keep=False,inplace=True)
# ----> 2 print(len(res))
#
# TypeError: object of type 'NoneType' has no len()

# %%
prob1 = np.array(prob)
original1 = np.array(original)
print(prob1.difference(original1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [52], in <cell line: 3>()
#       1 prob1 = np.array(prob)
#       2 original1 = np.array(original)
# ----> 3 print(prob1.difference(original1))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'difference'

# %%
result
# Out:
#                             0
# 0      66U0ASk1VHZsqIkpMjKX3B
# 1      5MhsZlmKJG6X5kTHkdwC4B
# 2      0GZoB8h0kqXn7XFm4Sj06k
# 3      35kahykNu00FPysz3C2euR
# 4      3G6hD9B2ZHOsgf4WfNu7X1
# ...                       ...
# 66245  3B4etxytImrRKQgV3XHjnR
# 66246  2KtS31kaWNHs12Q5B43Ixh
# 66247  25a7EWpbv4NjeUIP1PN6T1
# 66248  0MMyJUC3WNnFS1lit5pTjk
# 66249  4CdVzZTnf7JElTDw0kyUiN
#
# [66250 rows x 1 columns]

# %%
# result_merge.drop_duplicates(keep=False,inplace=True)
# result

# %%
# result_merge.to_csv('merged_both.csv')
