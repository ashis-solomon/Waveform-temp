# %%
import requests

# %%
base_url = 'https://api.spotify.com/v1/search'
access_token = ''

# %%
ref_url = "https://api.spotify.com/v1/search?q=track%3Amockingbird%2Bartist%3Aeminem&type=track%2Cartist"

# %%
url = ref_url

def get_search():
  response = requests.get(
      url,
      headers={
          "Authorization":f"Bearer {access_token}",
          'Content-Type': 'application/json'
          }
      )
  resp = response.json()
  return resp

# %%
resp = get_search()
print(type(resp))
# Out:
# <class 'dict'>

# %%
resp
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=track%3Amockingbird%2Bartist%3Aeminem&type=artist&offset=0&limit=20',
#   'items': [],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0},
#  'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3Amockingbird%2Bartist%3Aeminem&type=track&offset=0&limit=20',
#   'items': [],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0}}

# %%
print(resp['artists']['href'])
# Out:
# https://api.spotify.com/v1/search?query=track%3Amockingbird%2Bartist%3Aeminem&type=artist&offset=0&limit=20

# %%
# CORRECT CODE
headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer BQAfjdKCaMicL9kVus41ZHBh8NIc0nUOihV4tpN-Edgl0gyQy-2wqSty8PXJ4q01Rz31M-mRIDAJaemTwm79ENv1Vkre6rJ-JbkB2-HdtkeBzeIXfxNcweqvAYbXv67HXxSOgUzKHMP-IkmaHd45oxdLCSuL45bGgJ_KXvBEBiup7SKQD6w__5jucLvWIiSrTts',
}

params = {
    'q': 'track:Mockingbird',
    'type': 'track',
    'include_external': 'audio',
}
response = requests.get('https://api.spotify.com/v1/search', params=params, headers=headers)
resp = response.json()

# %%
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3AMockingbird&type=track&include_external=audio&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#        'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#        'id': '7dGJo4pcD2V6oG8kP0tJRR',
#        'name': 'Eminem',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
# ...
